# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
columns = ['sepal_width','sepal_length','species']
df[columns].head()
# Out:
#    sepal_width  sepal_length species
# 0          3.5           5.1  setosa
# 1          3.0           4.9  setosa
# 2          3.2           4.7  setosa
# 3          3.1           4.6  setosa
# 4          3.6           5.0  setosa

# %%
df.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df.filter(regex='\_')     # collects columns with '_'
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.filter(regex='length$')   # columns ending with 'length'
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
df.filter(regex='^sepal')    # columns starting with 'sepal'
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df.filter(regex='^(?!species$).*')     # columns without 'species'
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.loc[1:5,'sepal_width' : 'petal_width']
# Out:
#    sepal_width  petal_length  petal_width
# 1          3.0           1.4          0.2
# 2          3.2           1.3          0.2
# 3          3.1           1.5          0.2
# 4          3.6           1.4          0.2
# 5          3.9           1.7          0.4

# %%
df.iloc[:,[1,2,4]]
# Out:
#      sepal_width  petal_length    species
# 0            3.5           1.4     setosa
# 1            3.0           1.4     setosa
# 2            3.2           1.3     setosa
# 3            3.1           1.5     setosa
# 4            3.6           1.4     setosa
# ..           ...           ...        ...
# 145          3.0           5.2  virginica
# 146          2.5           5.0  virginica
# 147          3.0           5.2  virginica
# 148          3.4           5.4  virginica
# 149          3.0           5.1  virginica
#
# [150 rows x 3 columns]

# %%
df.iloc[-5:,[1,3]]
# Out:
#      sepal_width  petal_width
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8

# %%
df.loc[df['sepal_width'] > 3, ['petal_width','petal_length']].head()
# Out:
#    petal_width  petal_length
# 0          0.2           1.4
# 2          0.2           1.3
# 3          0.2           1.5
# 4          0.2           1.4
# 5          0.4           1.7
