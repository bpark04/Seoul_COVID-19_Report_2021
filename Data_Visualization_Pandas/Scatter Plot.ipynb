# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df.head()
# Out:
#           a         b         c         d
# 0  0.265130  0.291728  0.069810  0.253527
# 1  0.351822  0.021200  0.600630  0.893192
# 2  0.144851  0.150153  0.139219  0.836645
# 3  0.665576  0.038696  0.365269  0.874391
# 4  0.120550  0.392530  0.791263  0.721148

# %%
df.plot.scatter(x='a',y='b',s=50,grid=True)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkRed", label="Group 1")
df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
df.plot.scatter(x="a", y="b", c="c", s=30)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x="a", y="b", s=df["c"] * 200)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
