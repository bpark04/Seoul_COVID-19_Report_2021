# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df.head()
# Out:
#           a         b
# 0  0.210502  0.898654
# 1  0.886937  1.187014
# 2  0.013124  1.018106
# 3 -1.607512  4.504808
# 4  0.609087  3.776377

# %%
df.tail()
# Out:
#             a           b
# 995  0.440263  993.868599
# 996  0.142475  996.406680
# 997  0.864746  997.229278
# 998 -0.550487  996.764466
# 999  1.251016  998.483569

# %%
df.plot.hexbin(x="a", y="b", gridsize=20)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df["z"] = np.random.uniform(0, 3, 1000)
df.z
# Out:
# 0      1.891456
# 1      1.280403
# 2      2.201916
# 3      0.506857
# 4      2.266348
#          ...
# 995    0.292259
# 996    0.959629
# 997    0.391224
# 998    1.372934
# 999    0.166260
# Name: z, Length: 1000, dtype: float64

# %%
df.plot.hexbin(x="a", y="b", C="z", reduce_C_function=np.max, gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
